# %% [markdown]
# # Knowledge Ratchet: Reproduction Notebook
#
# This notebook reproduces all figures and tables from the paper.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sapelib import SAPEParams, SAPESimulator
from simulate import *

# %matplotlib inline

# %% [markdown]
# ## Figure 2: Parameter Sensitivity

# %%
figure_parameter_sensitivity(Path('figures'), n_runs=1000)
